# %% [markdown]
# ## Cargamos el primer dataset de google con la metadata de los restaurantes

# %%
from google.colab import auth
auth.authenticate_user()

# bibliotecas
from google.cloud import storage
import pandas as pd
import io

# cliente de almacenamiento
client = storage.Client()

# bucket y archivo
bucket_name = 'etl_archivos'
file_name = 'MetaDataGoogleRestaurants.csv'

# obtener el bucket
bucket = client.get_bucket(bucket_name)

# obtener el blob (archivo)
blob = bucket.blob(file_name)

# descargar el contenido del archivo como string
file_content = blob.download_as_string()

# leer el contenido como DataFrame
df_md = pd.read_csv(io.BytesIO(file_content))

df_md['platform'] = 'Google'
df_md.head()
# Out:
#                                     name  \
# 0                           San Soo Dang
# 1                           Vons Chicken
# 2  Sweet Rewards Gluten Free Bakery, LLC
# 3                        Vivi Bubble Tea
# 4                              Hale Pops
#
#                                              address  \
# 0  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 1  Vons Chicken, 12740 La Mirada Blvd, La Mirada,...
# 2  Sweet Rewards Gluten Free Bakery, LLC, 85 NE D...
# 3  Vivi Bubble Tea, 701 S 5th St, Philadelphia, P...
# 4   Hale Pops, 55-370 Kamehameha Hwy, Laie, HI 96762
#
#                                  gmap_id   latitude   longitude  \
# 0  0x80c2c778e3b73d33:0xbdc58662a4a97d49  34.058092 -118.292130
# 1  0x80dd2b4c8555edb7:0xfc33d65c4bdbef42  33.916402 -118.010855
# 2   0x87ec235c54d25b31:0x3b75fb5facc602f  41.616079  -93.865487
# 3  0x89c6c89efcaed69d:0xded973f6033e7dba  39.940293  -75.150923
# 4   0x7c00456eecad3111:0x8217f9600c51f33  21.637796 -157.920714
#
#                              category  avg_rating  num_of_reviews platform
# 0                 'Korean restaurant'         4.4              18   Google
# 1                        'Restaurant'         4.5              18   Google
# 2  'Bakery', 'Health food restaurant'         4.7              21   Google
# 3                        'Restaurant'         4.0               8   Google
# 4                        'Restaurant'         4.4              18   Google

# %% [markdown]
# ## Cambiamos las columnas que no nos sirven y generamos el business_id desde latitud y longitud

# %%
df_bgu = df_md.drop(columns = ['gmap_id'])
df_bgu['latitude'] = df_bgu['latitude'].astype(str)
df_bgu['longitude'] = df_bgu['longitude'].astype(str)
df_bgu['business_id'] = df_bgu['latitude'] + df_bgu['longitude']
df_bgu.rename(columns={'avg_rating':'stars'}, inplace = True)
df_bgu.rename(columns={'num_of_reviews':'review_count'}, inplace = True)
df_bgu.rename(columns={'category':'categories'}, inplace = True)
df_bgu.drop_duplicates(inplace=True)
df_bgu.head()
# Out:
#                                     name  \
# 0                           San Soo Dang
# 1                           Vons Chicken
# 2  Sweet Rewards Gluten Free Bakery, LLC
# 3                        Vivi Bubble Tea
# 4                              Hale Pops
#
#                                              address    latitude  \
# 0  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...  34.0580917
# 1  Vons Chicken, 12740 La Mirada Blvd, La Mirada,...  33.9164023
# 2  Sweet Rewards Gluten Free Bakery, LLC, 85 NE D...   41.616079
# 3  Vivi Bubble Tea, 701 S 5th St, Philadelphia, P...  39.9402929
# 4   Hale Pops, 55-370 Kamehameha Hwy, Laie, HI 96762  21.6377957
#
#       longitude                          categories  stars  review_count  \
# 0  -118.2921295                 'Korean restaurant'    4.4            18
# 1   -118.010855                        'Restaurant'    4.5            18
# 2    -93.865487  'Bakery', 'Health food restaurant'    4.7            21
# 3    -75.150923                        'Restaurant'    4.0             8
# 4  -157.9207142                        'Restaurant'    4.4            18
#
#   platform             business_id
# 0   Google  34.0580917-118.2921295
# 1   Google   33.9164023-118.010855
# 2   Google     41.616079-93.865487
# 3   Google    39.9402929-75.150923
# 4   Google  21.6377957-157.9207142

# %%
import re
# Function to extract city and state
def extract_city_state(address):
    if not isinstance(address, str):
        return pd.Series([None, None])
    pattern = r',\s*([^,]+),\s*([A-Z]{2})\s*\d{5}'
    match = re.search(pattern, address)
    if match:
        city = match.group(1).strip()
        state = match.group(2).strip()
        return pd.Series([city, state])
    return pd.Series([None, None])
# Apply the function to the dataframe
df_bgu[['city', 'state']] = df_bgu['address'].apply(extract_city_state)

# %%
df_bgu
# Out:
#                                          name  \
# 0                                San Soo Dang
# 1                                Vons Chicken
# 2       Sweet Rewards Gluten Free Bakery, LLC
# 3                             Vivi Bubble Tea
# 4                                   Hale Pops
# ...                                       ...
# 210948               House of Gourmet -- 食全食美
# 210949                      Asian Cuisine # 2
# 210950          Rosa’s Mexican Grill Chandler
# 210951                         Domino's Pizza
# 210952         The Green Room Of Libertyville
#
#                                                   address    latitude  \
# 0       San Soo Dang, 761 S Vermont Ave, Los Angeles, ...  34.0580917
# 1       Vons Chicken, 12740 La Mirada Blvd, La Mirada,...  33.9164023
# 2       Sweet Rewards Gluten Free Bakery, LLC, 85 NE D...   41.616079
# 3       Vivi Bubble Tea, 701 S 5th St, Philadelphia, P...  39.9402929
# 4        Hale Pops, 55-370 Kamehameha Hwy, Laie, HI 96762  21.6377957
# ...                                                   ...         ...
# 210948  House of Gourmet -- 食全食美, 2865 Sheridan Dr Sui...  42.9802514
# 210949  Asian Cuisine # 2, 302 N Federal Blvd, Riverto...  43.0269754
# 210950  Rosa’s Mexican Grill Chandler, 3002 N Arizona ...  33.3510567
# 210951  Domino's Pizza, 804 N Federal Blvd, Riverton, ...  43.0315264
# 210952  The Green Room Of Libertyville, 624 Milwaukee ...    42.28945
#
#            longitude                                         categories  \
# 0       -118.2921295                                'Korean restaurant'
# 1        -118.010855                                       'Restaurant'
# 2         -93.865487                 'Bakery', 'Health food restaurant'
# 3         -75.150923                                       'Restaurant'
# 4       -157.9207142                                       'Restaurant'
# ...              ...                                                ...
# 210948   -78.8273367         'Chinese restaurant', 'Sichuan restaurant'
# 210949   -108.380989                'Restaurant', 'Delivery Restaurant'
# 210950  -111.8429949                               'Mexican restaurant'
# 210951  -108.3816407  'Pizza delivery', 'Delivery Restaurant', 'Take...
# 210952   -87.9543861                                'Restaurant', 'Bar'
#
#         stars  review_count platform             business_id          city  \
# 0         4.4            18   Google  34.0580917-118.2921295   Los Angeles
# 1         4.5            18   Google   33.9164023-118.010855     La Mirada
# 2         4.7            21   Google     41.616079-93.865487        Waukee
# 3         4.0             8   Google    39.9402929-75.150923  Philadelphia
# 4         4.4            18   Google  21.6377957-157.9207142          Laie
# ...       ...           ...      ...                     ...           ...
# 210948    4.3            58   Google   42.9802514-78.8273367     Tonawanda
# 210949    4.3            38   Google   43.0269754-108.380989      Riverton
# 210950    4.4            88   Google  33.3510567-111.8429949      Chandler
# 210951    4.1           178   Google  43.0315264-108.3816407      Riverton
# 210952    4.6           228   Google     42.28945-87.9543861  Libertyville
#
#        state
# 0         CA
# 1         CA
# 2         IA
# 3         PA
# 4         HI
# ...      ...
# 210948    NY
# 210949    WY
# 210950    AZ
# 210951    WY
# 210952    IL
#
# [210953 rows x 11 columns]

# %% [markdown]
# ## Cargamos el archivo business de YELP

# %%
# bucket y archivo
bucket_name = 'etl_archivos'
file_name = 'business.csv'

# obtener el bucket
bucket = client.get_bucket(bucket_name)

# obtener el blob (archivo)
blob = bucket.blob(file_name)

# descargar el contenido del archivo como string
file_content = blob.download_as_string()

# leer el contenido como DataFrame
df_by = pd.read_csv(io.BytesIO(file_content))

df_by['platform'] = 'Yelp'
df_by.head()
# Out:
#               business_id                   name              address  \
# 0  MTSW4McQd7CbVtyjqoe9mw     St Honore Pastries          935 Race St
# 1  CF33F8-E6oudUQ46HnavjQ         Sonic Drive-In        615 S Main St
# 2  k0hlBqXX-Bt0vf1op7Jr1w  Tsevi's Pub And Grill    8025 Mackenzie Rd
# 3  bBDDEgkFA1Otx9Lfe7BZUQ         Sonic Drive-In  2312 Dickerson Pike
# 4  eEOYSgkmpB90uNA7lDOMRA  Vietnamese Food Truck                  NaN
#
#            city state   latitude  longitude  stars  review_count  \
# 0  Philadelphia    CA  39.955505 -75.155564    4.0            80
# 1  Ashland City    AZ  36.269593 -87.058943    2.0             6
# 2        Affton    TN  38.565165 -90.321087    3.0            19
# 3     Nashville    MO  36.208102 -86.768170    1.5            10
# 4     Tampa Bay    MO  27.955269 -82.456320    4.0            10
#
#                                           categories platform
# 0  Restaurants, Food, Bubble Tea, Coffee & Tea, B...     Yelp
# 1  Burgers, Fast Food, Sandwiches, Food, Ice Crea...     Yelp
# 2  Pubs, Restaurants, Italian, Bars, American (Tr...     Yelp
# 3  Ice Cream & Frozen Yogurt, Fast Food, Burgers,...     Yelp
# 4         Vietnamese, Food, Restaurants, Food Trucks     Yelp

# %% [markdown]
# ## Modificamos columnas y creamos business_id a partir de latitud y longitud

# %%
df_byu = df_by.drop(columns = ['business_id'])
df_byu['latitude'] = df_byu['latitude'].astype(str)
df_byu['longitude'] = df_byu['longitude'].astype(str)
df_byu['business_id'] = df_byu['latitude'] + df_byu['longitude']
df_byu.drop_duplicates(inplace=True)
df_byu.head()
# Out:
#                     name              address          city state    latitude  \
# 0     St Honore Pastries          935 Race St  Philadelphia    CA  39.9555052
# 1         Sonic Drive-In        615 S Main St  Ashland City    AZ   36.269593
# 2  Tsevi's Pub And Grill    8025 Mackenzie Rd        Affton    TN  38.5651648
# 3         Sonic Drive-In  2312 Dickerson Pike     Nashville    MO  36.2081024
# 4  Vietnamese Food Truck                  NaN     Tampa Bay    MO  27.9552692
#
#      longitude  stars  review_count  \
# 0  -75.1555641    4.0            80
# 1   -87.058943    2.0             6
# 2  -90.3210868    3.0            19
# 3  -86.7681696    1.5            10
# 4  -82.4563199    4.0            10
#
#                                           categories platform  \
# 0  Restaurants, Food, Bubble Tea, Coffee & Tea, B...     Yelp
# 1  Burgers, Fast Food, Sandwiches, Food, Ice Crea...     Yelp
# 2  Pubs, Restaurants, Italian, Bars, American (Tr...     Yelp
# 3  Ice Cream & Frozen Yogurt, Fast Food, Burgers,...     Yelp
# 4         Vietnamese, Food, Restaurants, Food Trucks     Yelp
#
#              business_id
# 0  39.9555052-75.1555641
# 1    36.269593-87.058943
# 2  38.5651648-90.3210868
# 3  36.2081024-86.7681696
# 4  27.9552692-82.4563199

# %% [markdown]
# ## Generamos el dataset unificado

# %%
# Unificar los dataframes uno debajo del otro
df_business_unificado = pd.concat([df_byu, df_bgu], ignore_index=True)

df_business_unificado.drop_duplicates(subset='business_id', keep='first', inplace= True)
df_business_unificado.reset_index(inplace=True, drop=True)
df_business_unificado
# Out:
#                                   name  \
# 0                   St Honore Pastries
# 1                       Sonic Drive-In
# 2                Tsevi's Pub And Grill
# 3                       Sonic Drive-In
# 4                Vietnamese Food Truck
# ...                                ...
# 254573                    Millsite Inn
# 254574               Asian Cuisine # 2
# 254575   Rosa’s Mexican Grill Chandler
# 254576                  Domino's Pizza
# 254577  The Green Room Of Libertyville
#
#                                                   address          city state  \
# 0                                             935 Race St  Philadelphia    CA
# 1                                           615 S Main St  Ashland City    AZ
# 2                                       8025 Mackenzie Rd        Affton    TN
# 3                                     2312 Dickerson Pike     Nashville    MO
# 4                                                     NaN     Tampa Bay    MO
# ...                                                   ...           ...   ...
# 254573          Millsite Inn, 44365 CO-72, Ward, CO 80481          Ward    CO
# 254574  Asian Cuisine # 2, 302 N Federal Blvd, Riverto...      Riverton    WY
# 254575  Rosa’s Mexican Grill Chandler, 3002 N Arizona ...      Chandler    AZ
# 254576  Domino's Pizza, 804 N Federal Blvd, Riverton, ...      Riverton    WY
# 254577  The Green Room Of Libertyville, 624 Milwaukee ...  Libertyville    IL
#
#           latitude     longitude  stars  review_count  \
# 0       39.9555052   -75.1555641    4.0            80
# 1        36.269593    -87.058943    2.0             6
# 2       38.5651648   -90.3210868    3.0            19
# 3       36.2081024   -86.7681696    1.5            10
# 4       27.9552692   -82.4563199    4.0            10
# ...            ...           ...    ...           ...
# 254573  40.0787237  -105.5026433    3.8            56
# 254574  43.0269754   -108.380989    4.3            38
# 254575  33.3510567  -111.8429949    4.4            88
# 254576  43.0315264  -108.3816407    4.1           178
# 254577    42.28945   -87.9543861    4.6           228
#
#                                                categories platform  \
# 0       Restaurants, Food, Bubble Tea, Coffee & Tea, B...     Yelp
# 1       Burgers, Fast Food, Sandwiches, Food, Ice Crea...     Yelp
# 2       Pubs, Restaurants, Italian, Bars, American (Tr...     Yelp
# 3       Ice Cream & Frozen Yogurt, Fast Food, Burgers,...     Yelp
# 4              Vietnamese, Food, Restaurants, Food Trucks     Yelp
# ...                                                   ...      ...
# 254573                              'American restaurant'   Google
# 254574                'Restaurant', 'Delivery Restaurant'   Google
# 254575                               'Mexican restaurant'   Google
# 254576  'Pizza delivery', 'Delivery Restaurant', 'Take...   Google
# 254577                                'Restaurant', 'Bar'   Google
#
#                    business_id
# 0        39.9555052-75.1555641
# 1          36.269593-87.058943
# 2        38.5651648-90.3210868
# 3        36.2081024-86.7681696
# 4        27.9552692-82.4563199
# ...                        ...
# 254573  40.0787237-105.5026433
# 254574   43.0269754-108.380989
# 254575  33.3510567-111.8429949
# 254576  43.0315264-108.3816407
# 254577     42.28945-87.9543861
#
# [254578 rows x 11 columns]

# %% [markdown]
# ## Exportamos el dataset unificado de business

# %%
# prompt: exportar a la nube en formato parquet

# Import necessary libraries
from google.cloud import storage

# Define the bucket and file names
bucket_name = "etl_archivos"
file_name = "BusinessUnificados.parquet"

# Create a storage client
client = storage.Client()

# Get the bucket
bucket = client.get_bucket(bucket_name)

# Create a new blob in the bucket
blob = bucket.blob(file_name)

# Convert the DataFrame to parquet format
df_business_unificado.to_parquet("temp.parquet")

# Upload the parquet file to the bucket
blob.upload_from_filename("temp.parquet")

# Delete the temporary file
# !rm temp.parquet

# %% [markdown]
# ## Cargamos el archivo de Reviews de Google

# %%
# bucket y archivo
bucket_name = 'etl_archivos'
file_name = 'MassachusettsGoogleReviews.csv'

# obtener el bucket
bucket = client.get_bucket(bucket_name)

# obtener el blob (archivo)
blob = bucket.blob(file_name)

# descargar el contenido del archivo como string
file_content = blob.download_as_string()

# leer el contenido como DataFrame
df_mgr = pd.read_csv(io.BytesIO(file_content))

df_mgr['user_id'] = df_mgr['user_id'].astype(str)
# mostrar el DataFrame
df_mgr.head()
# Out:
#                   user_id  rating  \
# 0  1.1803396075403138e+20       5
# 1  1.1016725077517186e+20       5
# 2  1.1221360671460452e+20       5
# 3  1.0817449247256507e+20       5
# 4  1.0899013265898385e+20       5
#
#                                                 text  \
# 0        People run it make sure you are comfortable
# 1                      When you need a helping hand.
# 2  Very Helpful and understanding people definite...
# 3  Very good place nice things but on Saturday th...
# 4                                      Awesome place
#
#                                  gmap_id        date platform
# 0  0x89e4a103dd188585:0xfadc47938337579f  2021-04-29   Google
# 1  0x89e4a103dd188585:0xfadc47938337579f  2021-03-10   Google
# 2  0x89e4a103dd188585:0xfadc47938337579f  2020-07-05   Google
# 3  0x89e4a103dd188585:0xfadc47938337579f  2020-02-19   Google
# 4  0x89e4a103dd188585:0xfadc47938337579f  2019-11-05   Google

# %% [markdown]
# ## Generamos el business_id a partir de la latitud y la longitud del otro archivo

# %%
df_join = pd.merge(df_mgr, df_md, how='inner', on='gmap_id')
df_join['latitude'] = df_join['latitude'].astype(str)
df_join['longitude'] = df_join['longitude'].astype(str)
df_join['business_id'] = df_join['latitude'] + df_join['longitude']
df_join.drop(columns=['name','address','platform_y','latitude','longitude','category','avg_rating','num_of_reviews','gmap_id'], inplace = True)
df_join.drop_duplicates(inplace=True)
df_join.head()
# Out:
#                   user_id  rating  \
# 0  1.0532458711744035e+20       4
# 1  1.0859745719720491e+20       5
# 2  1.1183954618982552e+20       5
# 3  1.1498631393680748e+20       5
# 4  1.0126531419117824e+20       1
#
#                                                 text        date platform_x  \
# 0  What a great experience. I tried the chicken t...  2018-01-13     Google
# 1  The owner, T, is a wonderful man. Super friend...  2018-06-25     Google
# 2  Love this place,  always have & always will.  ...  2017-07-10     Google
# 3  Awesome pizzas and subs. Their hawaiin pizza i...  2017-06-11     Google
# 4  This was the worst experience ever,  they told...  2016-03-16     Google
#
#            business_id
# 0  42.559072-70.881542
# 1  42.559072-70.881542
# 2  42.559072-70.881542
# 3  42.559072-70.881542
# 4  42.559072-70.881542

# %% [markdown]
# ## Cargamos el tips de YELP

# %%
# bucket y archivo
bucket_name = 'etl_archivos'
file_name = 'tipsYelp.csv'

# obtener el bucket
bucket = client.get_bucket(bucket_name)

# obtener el blob (archivo)
blob = bucket.blob(file_name)

# descargar el contenido del archivo como string
file_content = blob.download_as_string()

# leer el contenido como DataFrame
df_ty = pd.read_csv(io.BytesIO(file_content))

# mostrar el DataFrame
df_ty.head()
# Out:
#                   user_id             business_id  \
# 0  AGNUgVwnZUey3gcPCJ76iw  3uLgwr0qeCNMjKenHJwPGQ
# 1  NBN4MgHP9D3cw--SnauTkA  QoezRbYQncpRqyrLH6Iqjg
# 2  -copOvldyKh1qr-vzkDEvw  MYoRNLb5chwjQe3c_k37Gg
# 3  FjMQVZjSqY8syIO-53KFKw  hV-bABTK-glh5wj31ps_Jw
# 4  ld0AperBXk1h6UbqmM80zw  _uN0OudeJ3Zl_tf6nxg5ww
#
#                                                 text        date platform
# 0                     Avengers time with the ladies.  2012-05-18     Yelp
# 1  They have lots of good deserts and tasty cuban...  2013-02-05     Yelp
# 2             It's open even when you think it isn't  2013-08-18     Yelp
# 3                          Very decent fried chicken  2017-06-27     Yelp
# 4             Appetizers.. platter special for lunch  2012-10-06     Yelp

# %% [markdown]
# ## Generamos el business_id a partir de la latitud y la longitud del otro archivo

# %%
df_join_yelp = pd.merge(df_ty, df_by, how='inner', on='business_id')
df_join_yelp['rating'] = 'NaN'
df_join_yelp['latitude'] = df_join_yelp['latitude'].astype(str)
df_join_yelp['longitude'] = df_join_yelp['longitude'].astype(str)
df_join_yelp['business_id'] = df_join_yelp['latitude'] + df_join_yelp['longitude']
df_join_yelp.drop(columns=['address','platform_y','latitude','longitude','categories','city','state','stars','review_count'], inplace = True)
df_join_yelp.drop_duplicates(inplace=True)
df_join_yelp.head()
# Out:
#                   user_id           business_id  \
# 0  NBN4MgHP9D3cw--SnauTkA  27.9658653-82.443197
# 1  DWryovIM4VF2vim4p6WYaw  27.9658653-82.443197
# 2  DWryovIM4VF2vim4p6WYaw  27.9658653-82.443197
# 3  boRCdL8ez95KwzWe69VoUg  27.9658653-82.443197
# 4  DWryovIM4VF2vim4p6WYaw  27.9658653-82.443197
#
#                                                 text        date platform_x  \
# 0  They have lots of good deserts and tasty cuban...  2013-02-05       Yelp
# 1                              Turkey and roast beef  2012-10-11       Yelp
# 2                              Coffee and baby bread  2012-10-24       Yelp
# 3  Such a great place to come and get a Cuban san...  2016-10-02       Yelp
# 4              My last time. Continental and a Cuban  2012-11-09       Yelp
#
#                         name rating
# 0  La Segunda Central Bakery    NaN
# 1  La Segunda Central Bakery    NaN
# 2  La Segunda Central Bakery    NaN
# 3  La Segunda Central Bakery    NaN
# 4  La Segunda Central Bakery    NaN

# %% [markdown]
# #Unimos los dos datasets de reviews

# %%
# Unificar los dataframes uno debajo del otro
import uuid
df_reviews_unificado = pd.concat([df_join_yelp, df_join], ignore_index=True)
df_reviews_unificado['date'] = pd.to_datetime(df_reviews_unificado['date'])
# Extraer el año
df_reviews_unificado['year'] = df_reviews_unificado['date'].dt.year

# Extraer el semestre
df_reviews_unificado['semester'] = (df_reviews_unificado['date'].dt.month - 1) // 6 + 1
df_reviews_unificado['review_id'] = [uuid.uuid4() for _ in range(len(df_reviews_unificado))]
df_reviews_unificado.drop(columns =['name'], inplace= True)
df_reviews_unificado
# Out:
#                        user_id            business_id  \
# 0       NBN4MgHP9D3cw--SnauTkA   27.9658653-82.443197
# 1       DWryovIM4VF2vim4p6WYaw   27.9658653-82.443197
# 2       DWryovIM4VF2vim4p6WYaw   27.9658653-82.443197
# 3       boRCdL8ez95KwzWe69VoUg   27.9658653-82.443197
# 4       DWryovIM4VF2vim4p6WYaw   27.9658653-82.443197
# ...                        ...                    ...
# 867494   1.159423870758638e+20  42.0806616-70.9304844
# 867495   1.140124865891358e+20  42.0806616-70.9304844
# 867496   1.019629264472351e+20  42.0806616-70.9304844
# 867497  1.0392610124987267e+20  42.0806616-70.9304844
# 867498  1.0529620867719912e+20  42.0806616-70.9304844
#
#                                                      text       date  \
# 0       They have lots of good deserts and tasty cuban... 2013-02-05
# 1                                   Turkey and roast beef 2012-10-11
# 2                                   Coffee and baby bread 2012-10-24
# 3       Such a great place to come and get a Cuban san... 2016-10-02
# 4                   My last time. Continental and a Cuban 2012-11-09
# ...                                                   ...        ...
# 867494                                                NaN 2020-07-27
# 867495                                                NaN 2017-07-20
# 867496                                                NaN 2019-04-14
# 867497                                                NaN 2019-12-12
# 867498                                                NaN 2018-05-16
#
#        platform_x rating  year  semester                             review_id
# 0            Yelp    NaN  2013         1  b569b2f5-7ff0-4f58-b57a-c7c461ad276c
# 1            Yelp    NaN  2012         2  42ef67fd-62cc-44d5-8b3f-cbba9a5803d9
# 2            Yelp    NaN  2012         2  ffc75569-8fb6-46aa-8029-7ac691563089
# 3            Yelp    NaN  2016         2  d8ec0978-d40e-499e-b07f-dfbab4025304
# 4            Yelp    NaN  2012         2  bb4bf6c5-ff25-496e-b84e-a3101f149302
# ...           ...    ...   ...       ...                                   ...
# 867494     Google      5  2020         2  40ebc6ef-c17f-4c88-bd96-c86eb27ce904
# 867495     Google      5  2017         2  68380d6c-2193-44d8-9397-e68a9dbb69de
# 867496     Google      5  2019         1  0f93ae35-e189-40a9-badc-64c771f91684
# 867497     Google      3  2019         2  4fe38ffc-9e79-4322-94f4-faf9a744be3c
# 867498     Google      4  2018         1  f1deea6a-46ea-4730-af68-248447098973
#
# [867499 rows x 9 columns]

# %% [markdown]
# ## Cargamos el dataset unificado a la nube, en parquet para que pueda ser subido a BigQuery

# %%
# prompt: TypeError: binary file expected, got text file

import io
df_reviews_unificado['rating'] = df_reviews_unificado['rating'].astype(str)
df_reviews_unificado['review_id'] = df_reviews_unificado['review_id'].astype(str)

# Create a StringIO object to hold the DataFrame in memory
sio = io.BytesIO()

# Write the DataFrame to the StringIO object in Parquet format
df_reviews_unificado.to_parquet(sio)

# Create a client object for interacting with Cloud Storage
client = storage.Client()

# Create a bucket object for the desired bucket
bucket = client.get_bucket('etl_archivos')

# Create a blob object for the desired file
blob = bucket.blob('ReviewsUnificados.parquet')

# Upload the DataFrame from the StringIO object to the blob
blob.upload_from_string(sio.getvalue())

# %% [markdown]
# ## Cargamos el archivo users del dataset de YELP

# %%
# bucket y archivo
bucket_name = 'etl_archivos'
file_name = 'users.csv'

# obtener el bucket
bucket = client.get_bucket(bucket_name)

# obtener el blob (archivo)
blob = bucket.blob(file_name)

# descargar el contenido del archivo como string
file_content = blob.download_as_string()

# leer el contenido como DataFrame
df_uy = pd.read_csv(io.BytesIO(file_content))
df_uy['platform'] = 'Yelp'
# mostrar el DataFrame
df_uy.head()
# Out:
#                   user_id  review_count  average_stars  fans
# 0  qVc8ODYU5SZjKXVBgXdI7w           585           3.91   267
# 1  j14WgRoU_-2ZE1aw1dXrJg          4333           3.74  3138
# 2  2WnXYQFK0hXEoTxPtV2zvg           665           3.32    52
# 3  SZDeASXq7o05mMNLshsdIA           224           4.27    28
# 4  hA5lMy-EnncsH4JoR-hFGQ            79           3.54     1

# %%
# bucket y archivo
bucket_name = 'etl_archivos'
file_name = 'Reviews_por_estado.csv'

# obtener el bucket
bucket = client.get_bucket(bucket_name)

# obtener el blob (archivo)
blob = bucket.blob(file_name)

# descargar el contenido del archivo como string
file_content = blob.download_as_string()

# leer el contenido como DataFrame
df_ry = pd.read_csv(io.BytesIO(file_content))

# mostrar el DataFrame
df_ry
# Out:
#    state  num_reviews
# 0     DE        75950
# 1     MO       339402
# 2     IL        70445
# 3     CA       153053
# 4     AZ       321061
# 5     LA       323053
# 6     NJ       276683
# 7     FL       824870
# 8     NV       256647
# 9     ID       150367
# 10    IN       314643
# 11    TN       370043
# 12    TX           80
# 13    PA      1070508
# 14    AB       177355
# 15    VI           42
# 16    VT            8
# 17    WA          114
# 18    CO          111
# 19    HI           18
# 20    MI           18

# %% [markdown]
# ## No hay reseñas en Massachusets en este ultimo archivo, por el momento no lo utilizaremos
