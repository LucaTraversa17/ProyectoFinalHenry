# %%
from google.colab import auth
auth.authenticate_user()

from google.cloud import storage
import pandas as pd
import pickle
import io

# Cliente de almacenamiento
client = storage.Client()

# Nombre del bucket y archivo
bucket_name = 'pf_datawarehouse'
file_name = 'business.pkl'

# Obtener el bucket
bucket = client.bucket(bucket_name)

# Obtener el blob (archivo) del bucket
blob = bucket.blob(file_name)

# Descargar el archivo como bytes
pickle_data = blob.download_as_bytes()

# Cargar el archivo pickle en un DataFrame de Pandas
with io.BytesIO(pickle_data) as f:
    df_business = pd.read_pickle(f)

# Mostrar las primeras filas del DataFrame
df_business.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
# 2             5255 E Broadway Blvd         Tucson   NaN       85711
# 3                      935 Race St   Philadelphia    CA       19107
# 4                    101 Walnut St     Green Lane    MO       18054
#
#     latitude   longitude stars review_count  ... state postal_code latitude  \
# 0  34.426679 -119.711197   5.0            7  ...   NaN         NaN      NaN
# 1  38.551126  -90.335695   3.0           15  ...   NaN         NaN      NaN
# ...

# %%
df_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150346 entries, 0 to 150345
# Data columns (total 28 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   150346 non-null  object
#  1   name          150346 non-null  object
#  2   address       150346 non-null  object
#  3   city          150346 non-null  object
#  4   state         150343 non-null  object
#  5   postal_code   150346 non-null  object
#  6   latitude      150346 non-null  object
#  7   longitude     150346 non-null  object
#  8   stars         150346 non-null  object
#  9   review_count  150346 non-null  object
#  10  is_open       150346 non-null  object
#  11  attributes    136602 non-null  object
#  12  categories    150243 non-null  object
#  13  hours         127123 non-null  object
#  14  business_id   5 non-null       object
#  15  name          5 non-null       object
#  16  address       5 non-null       object
# ...

# %%
df_business.isnull().sum()
# Out:
# business_id          0
# name                 0
# address              0
# city                 0
# state                3
# postal_code          0
# latitude             0
# longitude            0
# stars                0
# review_count         0
# is_open              0
# attributes       13744
# categories         103
# hours            23223
# business_id     150341
# name            150341
# address         150341
# city            150341
# state           150341
# postal_code     150341
# latitude        150341
# longitude       150341
# stars           150341
# review_count    150341
# is_open         150341
# attributes      150341
# categories      150341
# hours           150341
# dtype: int64

# %%
df_business.shape
# Out:
# (150346, 28)

# %%
# Convertir columnas tipo diccionario a cadenas antes de buscar duplicados
df_business_str = df_business.applymap(lambda x: str(x) if isinstance(x, dict) else x)

# vemos filas duplicadas
df_business_str.duplicated().sum()
# Out:
# 0

# %%
# eliminar las columnas duplicadas por nombre
df_business = df_business.loc[:, ~df_business.columns.duplicated()]

# Identificar las columnas que tienen todos sus valores nulos
columns_with_all_nulls = df_business.columns[df_business.isnull().all()]

# Eliminar las columnas con todos los valores nulos del DataFrame
df_business.drop(columns=columns_with_all_nulls, inplace=True)

df_business.head(10)
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# 5  CF33F8-E6oudUQ46HnavjQ            Sonic Drive-In
# 6  n_0UpQx1hsNbnPUSlodU8w           Famous Footwear
# 7  qkRM_2X51Yqxk3btlwAQIg            Temple Beth-El
# 8  k0hlBqXX-Bt0vf1op7Jr1w     Tsevi's Pub And Grill
# 9  bBDDEgkFA1Otx9Lfe7BZUQ            Sonic Drive-In
#
#                                       address            city state  \
# 0                      1616 Chapala St, Ste 2   Santa Barbara   NaN
# 1             87 Grasso Plaza Shopping Center          Affton   NaN
# 2                        5255 E Broadway Blvd          Tucson   NaN
# 3                                 935 Race St    Philadelphia    CA
# ...

# %%
df_business.shape
# Out:
# (150346, 14)

# %%
df_business.isnull().sum()
# Out:
# business_id         0
# name                0
# address             0
# city                0
# state               3
# postal_code         0
# latitude            0
# longitude           0
# stars               0
# review_count        0
# is_open             0
# attributes      13744
# categories        103
# hours           23223
# dtype: int64

# %%
# eliminar primeras columnas
df_business.drop(columns=['hours', 'attributes', 'is_open'], inplace=True)

df_business.head(10)
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# 5  CF33F8-E6oudUQ46HnavjQ            Sonic Drive-In
# 6  n_0UpQx1hsNbnPUSlodU8w           Famous Footwear
# 7  qkRM_2X51Yqxk3btlwAQIg            Temple Beth-El
# 8  k0hlBqXX-Bt0vf1op7Jr1w     Tsevi's Pub And Grill
# 9  bBDDEgkFA1Otx9Lfe7BZUQ            Sonic Drive-In
#
#                                       address            city state  \
# 0                      1616 Chapala St, Ste 2   Santa Barbara   NaN
# 1             87 Grasso Plaza Shopping Center          Affton   NaN
# 2                        5255 E Broadway Blvd          Tucson   NaN
# 3                                 935 Race St    Philadelphia    CA
# ...

# %%
# eliminar 2das columnas irrelevantes
df_business.drop(columns=['postal_code', 'name'], inplace=True)

df_business.head(10)
# Out:
#               business_id                                     address  \
# 0  Pns2l4eNsfO8kk83dixA6A                      1616 Chapala St, Ste 2
# 1  mpf3x-BjTdTEA3yCZrAYPw             87 Grasso Plaza Shopping Center
# 2  tUFrWirKiKi_TAnsVWINQQ                        5255 E Broadway Blvd
# 3  MTSW4McQd7CbVtyjqoe9mw                                 935 Race St
# 4  mWMc6_wTdE0EUBKIGXDVfA                               101 Walnut St
# 5  CF33F8-E6oudUQ46HnavjQ                               615 S Main St
# 6  n_0UpQx1hsNbnPUSlodU8w  8522 Eager Road, Dierbergs Brentwood Point
# 7  qkRM_2X51Yqxk3btlwAQIg                          400 Pasadena Ave S
# 8  k0hlBqXX-Bt0vf1op7Jr1w                           8025 Mackenzie Rd
# 9  bBDDEgkFA1Otx9Lfe7BZUQ                         2312 Dickerson Pike
#
#              city state   latitude   longitude stars review_count  \
# 0   Santa Barbara   NaN  34.426679 -119.711197   5.0            7
# ...

# %%
# Filtrar filas donde la columna "categories" contenga las palabras "Restaurants"
df_restaurants = df_business[df_business['categories'].str.contains('Restaurants', na=False)]

df_restaurants.head()
# Out:
#                business_id              address          city state  \
# 3   MTSW4McQd7CbVtyjqoe9mw          935 Race St  Philadelphia    CA
# 5   CF33F8-E6oudUQ46HnavjQ        615 S Main St  Ashland City    AZ
# 8   k0hlBqXX-Bt0vf1op7Jr1w    8025 Mackenzie Rd        Affton    TN
# 9   bBDDEgkFA1Otx9Lfe7BZUQ  2312 Dickerson Pike     Nashville    MO
# 11  eEOYSgkmpB90uNA7lDOMRA                          Tampa Bay    MO
#
#      latitude  longitude stars review_count  \
# 3   39.955505 -75.155564   4.0           80
# 5   36.269593 -87.058943   2.0            6
# 8   38.565165 -90.321087   3.0           19
# 9   36.208102  -86.76817   1.5           10
# 11  27.955269  -82.45632   4.0           10
#
#                                            categories
# 3   Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 5   Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# 8   Pubs, Restaurants, Italian, Bars, American (Tr...
# 9   Ice Cream & Frozen Yogurt, Fast Food, Burgers,...
# ...

# %%
# Cantidad de restaurantes
print(f"Cantidad de restaurantes: {len(df_restaurants)}")
# Out:
# Cantidad de restaurantes: 52268

# %%
# Guardar el DataFrame como un archivo CSV en Google Cloud Storage
df_restaurants.to_csv('gs://etl_archivos/business.csv', index=False)
